# %% [markdown]
# # Controller Services

# %% [markdown]
# ## AvroReader

# %% [markdown]
# Tiene que tener la siguiente configuración
# ![imagen_2025-05-15_142858496.png](data:image/png;base64,...)

# %% [markdown]
# ## AvroRecordSetWriter

# %% [markdown]
# Tiene que tener la siguiente configuración
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## CSVReader

# %% [markdown]
# Tiene que tener la siguiente configuracion
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# El cual el contenido de "Schema Text" es el siguiente:

# %%
{
  "type": "record",
  "name": "ETFPriceData",
  "namespace": "com.example",
  "fields": [
    { "name": "fund_symbol", "type": "string" },
    { "name": "price_date", "type": { "type": "int", "logicalType": "date" } },
    { "name": "open", "type": ["null", "double"] },
    { "name": "high", "type": ["null", "double"] },
    { "name": "low", "type": ["null", "double"] },
    { "name": "close", "type": ["null", "double"] },
    { "name": "adj_close", "type": ["null", "double"] },
    { "name": "volume", "type": ["null", "long"] },
    { "name": "clasificacion", "type": ["null", "int"] },
    { "name": "rentabilidad_x", "type": ["null", "double"] },
    { "name": "rent_diaria", "type": ["null", "double"] },
    { "name": "rent_trimestre", "type": ["null", "double"] },
    { "name": "rent_anual", "type": ["null", "double"] },
    { "name": "rent_total_acum", "type": ["null", "double"] }
  ]
}

# %% [markdown]
# ## CassandraSessionProvider

# %% [markdown]
# Tiene que tener la siguiente configuracion
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Processors

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## GetFile

# %% [markdown]
# Tiene que estar configurado asi
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ConvertRecord

# %% [markdown]
# Tiene que estar configurado asi
#
# ![image.png](data:image/png;base64,...)
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## PutHDFS

# %% [markdown]
# Tiene que estar configurado asi:
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## PutCassandraRecord

# %% [markdown]
# Tiene que estar configurado asi:
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
